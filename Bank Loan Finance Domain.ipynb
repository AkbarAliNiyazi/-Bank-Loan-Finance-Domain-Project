# %% [markdown]
# # Bank Loan Finance Domain Project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

import warnings
warnings.simplefilter("ignore")

# %%
df = pd.read_csv('C:\\Anaconda file\\My Project\\bank loan.csv')
df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
df.tail()
# Out:
#       age            job  marital  education default  balance housing loan  \
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
df.shape
# Out:
# (4521, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %%
df['balance']
# Out:
# 0       1787
# 1       4789
# 2       1350
# 3       1476
# 4          0
#         ...
# 4516    -333
# 4517   -3313
# 4518     295
# 4519    1137
# 4520    1136
# Name: balance, Length: 4521, dtype: int64

# %%
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["balance"].describe()
# Out:
# count     4521.000000
# mean      1422.657819
# std       3009.638142
# min      -3313.000000
# 25%         69.000000
# 50%        444.000000
# 75%       1480.000000
# max      71188.000000
# Name: balance, dtype: float64

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
df['age'].unique()
# Out:
# array([30, 33, 35, 59, 36, 39, 41, 43, 20, 31, 40, 56, 37, 25, 38, 42, 44,
#        26, 55, 67, 53, 68, 32, 49, 78, 23, 52, 34, 61, 45, 48, 57, 54, 63,
#        51, 29, 50, 27, 60, 28, 21, 58, 22, 46, 24, 77, 75, 47, 70, 65, 64,
#        62, 66, 19, 81, 83, 80, 71, 72, 69, 79, 73, 86, 74, 76, 87, 84],
#       dtype=int64)

# %%
df['age'].value_counts()
# Out:
# age
# 34    231
# 32    224
# 31    199
# 36    188
# 33    186
#      ...
# 68      2
# 87      1
# 81      1
# 86      1
# 84      1
# Name: count, Length: 67, dtype: int64

# %%
df['job'].unique()
# Out:
# array(['unemployed', 'services', 'management', 'blue-collar',
#        'self-employed', 'technician', 'entrepreneur', 'admin.', 'student',
#        'housemaid', 'retired', 'unknown'], dtype=object)

# %%
df['job'].value_counts()
# Out:
# job
# management       969
# blue-collar      946
# technician       768
# admin.           478
# services         417
# retired          230
# self-employed    183
# entrepreneur     168
# unemployed       128
# housemaid        112
# student           84
# unknown           38
# Name: count, dtype: int64

# %%
df['marital'].unique()
# Out:
# array(['married', 'single', 'divorced'], dtype=object)

# %%
df['marital'].value_counts()
# Out:
# marital
# married     2797
# single      1196
# divorced     528
# Name: count, dtype: int64

# %%
df['education'].unique()
# Out:
# array(['primary', 'secondary', 'tertiary', 'unknown'], dtype=object)

# %%
df['education'].value_counts()
# Out:
# education
# secondary    2306
# tertiary     1350
# primary       678
# unknown       187
# Name: count, dtype: int64

# %%
df['balance'].unique()
# Out:
# array([ 1787,  4789,  1350, ...,  -333, -3313,  1137], dtype=int64)

# %%
df['balance'].value_counts()
# Out:
# balance
# 0       357
# 2        24
# 1        15
# 4        13
# 5        11
#        ...
# 539       1
# 1041      1
# 464       1
# 7702      1
# 1137      1
# Name: count, Length: 2353, dtype: int64

# %%
df['loan'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df['loan'].value_counts()
# Out:
# loan
# no     3830
# yes     691
# Name: count, dtype: int64

# %%
df['housing'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df['housing'].value_counts()
# Out:
# housing
# yes    2559
# no     1962
# Name: count, dtype: int64

# %%
df['contact'].unique()
# Out:
# array(['cellular', 'unknown', 'telephone'], dtype=object)

# %%
df['contact'].value_counts()
# Out:
# contact
# cellular     2896
# unknown      1324
# telephone     301
# Name: count, dtype: int64

# %%
df['duration'].unique()
# Out:
# array([  79,  220,  185,  199,  226,  141,  341,  151,   57,  313,  273,
#         113,  328,  261,   89,  189,  239,  114,  250,  148,   96,  140,
#         109,  125,  169,  182,  247,  119,  149,   74,  897,   81,   40,
#         958,  354,  150,   97,  132,  765,   16,  609,  106,  365,  205,
#          11,  105,   59,  425,  204,  181, 1018, 1740,   98,  441,  272,
#         159,  295,  314,  579,  554,  323,  227,  134,  223,  155,  130,
#         630,  164,  268,  380,  154,  221,   67,  367,   87,  701,  652,
#          63,  398,  224,  406,   60,  521,  279,  203,  201,  372,  391,
#         165,  231,  291,  233,  473,  736,  337,  553,  345,   65,    9,
#         259,  371,  280,  243,  435,  258,    7,  317,   76,  170,  386,
#          83,   69,  564,  588,  779,  281, 1877,   51,   32,  176,  161,
#         187,   24,   85,  236,   54,   71,  489,   39,  455,   86,  190,
#          45,  168,  194,  103,  333,  102,   92,  213,  289,   77,  324,
# ...

# %%
df['duration'].value_counts()
# Out:
# duration
# 123     27
# 104     25
# 119     23
# 77      22
# 58      22
#         ..
# 762      1
# 602      1
# 923      1
# 1032     1
# 660      1
# Name: count, Length: 875, dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
df['campaign'].unique()
# Out:
# array([ 1,  4,  2,  5,  3,  6, 18, 10,  9,  7, 12, 14, 13, 24, 11,  8, 29,
#        32, 16, 22, 15, 30, 25, 21, 17, 19, 23, 20, 50, 28, 31, 44],
#       dtype=int64)

# %%
df['campaign'].value_counts()
# Out:
# campaign
# 1     1734
# 2     1264
# 3      558
# 4      325
# 5      167
# 6      155
# 7       75
# 8       56
# 9       30
# 10      27
# 11      22
# 12      21
# 13      17
# 14      10
# 15       9
# 16       8
# 17       7
# 18       7
# 25       4
# 19       3
# 20       3
# 28       3
# 24       3
# 32       2
# 21       2
# 23       2
# 22       2
# 31       1
# 29       1
# 50       1
# 30       1
# 44       1
# Name: count, dtype: int64

# %%
df['day'].unique()
# Out:
# array([19, 11, 16,  3,  5, 23, 14,  6, 17, 20, 13, 30, 29, 27,  7, 18, 12,
#        21, 26, 22,  2,  4, 15,  8, 28,  9,  1, 10, 31, 25, 24],
#       dtype=int64)

# %%
df['day'].value_counts()
# Out:
# day
# 20    257
# 18    226
# 19    201
# 21    198
# 14    195
# 17    191
# 7     190
# 6     187
# 28    181
# 5     181
# 8     180
# 29    175
# 15    174
# 30    168
# 13    166
# 16    164
# 9     163
# 11    152
# 12    151
# 4     139
# 2     114
# 27    113
# 26    110
# 3     105
# 23    102
# 22     86
# 25     80
# 31     59
# 10     50
# 24     36
# 1      27
# Name: count, dtype: int64

# %%
continuous = ['age', 'balance', 'duration']

discrete_count = ['campaign', 'pdays', 'day', 'previous']

discrete_categorical = ['job', 'marital', 'education', 'default', 'housing', 'loan', 
                        'contact', 'month', 'poutcome', 'y']

# %%
df[continuous].describe()
# Out:
#                age       balance     duration
# count  4521.000000   4521.000000  4521.000000
# mean     41.170095   1422.657819   263.961292
# std      10.576211   3009.638142   259.856633
# min      19.000000  -3313.000000     4.000000
# 25%      33.000000     69.000000   104.000000
# 50%      39.000000    444.000000   185.000000
# 75%      49.000000   1480.000000   329.000000
# max      87.000000  71188.000000  3025.000000

# %%
df[discrete_count].describe()
# Out:
#           campaign        pdays          day     previous
# count  4521.000000  4521.000000  4521.000000  4521.000000
# mean      2.793630    39.766645    15.915284     0.542579
# std       3.109807   100.121124     8.247667     1.693562
# min       1.000000    -1.000000     1.000000     0.000000
# 25%       1.000000    -1.000000     9.000000     0.000000
# 50%       2.000000    -1.000000    16.000000     0.000000
# 75%       3.000000    -1.000000    21.000000     0.000000
# max      50.000000   871.000000    31.000000    25.000000

# %%
plt.hist(df["balance"], bins=10)
plt.show()

# %%
plt.hist(df["duration"], bins=10)
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
df.groupby("job")["loan"].describe()
# Out:
#               count unique top freq
# job
# admin.          478      2  no  387
# blue-collar     946      2  no  790
# entrepreneur    168      2  no  127
# housemaid       112      2  no   99
# management      969      2  no  849
# retired         230      2  no  198
# self-employed   183      2  no  153
# services        417      2  no  343
# student          84      2  no   83
# technician      768      2  no  649
# unemployed      128      2  no  115
# unknown          38      2  no   37

# %%
df.groupby("job")["loan"].describe().transpose()
# Out:
# job    admin. blue-collar entrepreneur housemaid management retired  \
# count     478         946          168       112        969     230
# unique      2           2            2         2          2       2
# top        no          no           no        no         no      no
# freq      387         790          127        99        849     198
#
# job    self-employed services student technician unemployed unknown
# count            183      417      84        768        128      38
# unique             2        2       2          2          2       2
# top               no       no      no         no         no      no
# freq             153      343      83        649        115      37

# %%
df.groupby("job")["loan"].min()
# Out:
# job
# admin.           no
# blue-collar      no
# entrepreneur     no
# housemaid        no
# management       no
# retired          no
# self-employed    no
# services         no
# student          no
# technician       no
# unemployed       no
# unknown          no
# Name: loan, dtype: object

# %%
df.groupby("job")["loan"].max()
# Out:
# job
# admin.           yes
# blue-collar      yes
# entrepreneur     yes
# housemaid        yes
# management       yes
# retired          yes
# self-employed    yes
# services         yes
# student          yes
# technician       yes
# unemployed       yes
# unknown          yes
# Name: loan, dtype: object

# %%
df.groupby("marital")["loan"].describe()
# Out:
#          count unique top  freq
# marital
# divorced   528      2  no   438
# married   2797      2  no  2344
# single    1196      2  no  1048

# %%
df.groupby("marital")["loan"].max()
# Out:
# marital
# divorced    yes
# married     yes
# single      yes
# Name: loan, dtype: object

# %%
df.groupby("job")["balance"].describe()
# Out:
#                count         mean          std     min     25%    50%  \
# job
# admin.         478.0  1226.736402  2370.119128  -967.0   62.25  430.0
# blue-collar    946.0  1085.161734  2040.218220 -1400.0   61.00  408.5
# entrepreneur   168.0  1645.125000  4441.303620 -2082.0   67.50  365.5
# housemaid      112.0  2083.803571  4603.836647  -759.0   24.25  296.5
# management     969.0  1766.928793  3267.733077 -1746.0   99.00  577.0
# retired        230.0  2319.191304  5846.379889 -1206.0  155.25  672.5
# self-employed  183.0  1392.409836  2479.640999 -3313.0  137.00  483.0
# services       417.0  1103.956835  2445.239976 -1202.0   33.00  288.0
# student         84.0  1543.821429  2579.886671  -230.0   59.75  422.5
# technician     768.0  1330.996094  2630.253390 -1680.0   64.00  434.5
# unemployed     128.0  1089.421875  1692.267628  -872.0   23.75  473.5
# unknown         38.0  1501.710526  1957.258258     0.0  256.75  655.5
#
#                    75%      max
# job
# ...

# %%
df.groupby("job")["balance"].describe().transpose()
# Out:
# job          admin.   blue-collar  entrepreneur     housemaid    management  \
# count    478.000000    946.000000     168.00000    112.000000    969.000000
# mean    1226.736402   1085.161734    1645.12500   2083.803571   1766.928793
# std     2370.119128   2040.218220    4441.30362   4603.836647   3267.733077
# min     -967.000000  -1400.000000   -2082.00000   -759.000000  -1746.000000
# 25%       62.250000     61.000000      67.50000     24.250000     99.000000
# 50%      430.000000    408.500000     365.50000    296.500000    577.000000
# 75%     1320.750000   1204.500000    1428.75000   1854.500000   1859.000000
# max    22171.000000  16353.000000   42045.00000  26965.000000  27359.000000
#
# job         retired  self-employed      services       student    technician  \
# count    230.000000     183.000000    417.000000     84.000000    768.000000
# mean    2319.191304    1392.409836   1103.956835   1543.821429   1330.996094
# ...

# %%
df.groupby("job")["duration"].describe().transpose()
# Out:
# job         admin.  blue-collar  entrepreneur    housemaid   management  \
# count   478.000000   946.000000    168.000000   112.000000   969.000000
# mean    234.669456   278.161734    285.476190   292.633929   260.536636
# std     236.874175   265.348935    313.827042   277.948598   254.516417
# min       8.000000     5.000000     10.000000    15.000000     4.000000
# 25%      89.000000   109.000000    113.000000   118.750000   104.000000
# 50%     161.000000   204.000000    195.000000   183.000000   176.000000
# 75%     272.000000   341.750000    349.750000   368.500000   317.000000
# max    1713.000000  2456.000000   2769.000000  1558.000000  2087.000000
#
# job        retired  self-employed     services      student   technician  \
# count   230.000000     183.000000   417.000000    84.000000   768.000000
# mean    285.656522     264.125683   262.486811   248.690476   252.178385
# std     242.512484     278.177468   259.997440   208.090514   246.135579
# ...

# %%
df.groupby("marital")["balance"].describe().transpose()
# Out:
# marital      divorced       married        single
# count      528.000000   2797.000000   1196.000000
# mean      1122.390152   1463.195567   1460.414716
# std       2199.922010   3188.571513   2879.810214
# min      -1148.000000  -3313.000000  -1313.000000
# 25%         31.250000     72.000000     81.000000
# 50%        367.500000    452.000000    462.000000
# 75%       1245.000000   1521.000000   1509.000000
# max      26306.000000  71188.000000  27733.000000

# %%
df.groupby("marital")["duration"].describe().transpose()
# Out:
# marital     divorced      married       single
# count     528.000000  2797.000000  1196.000000
# mean      279.232955   256.528781   274.601171
# std       279.813039   249.714248   273.195384
# min         5.000000     4.000000     5.000000
# 25%       106.000000   104.000000   103.000000
# 50%       186.000000   183.000000   191.000000
# 75%       347.000000   320.000000   344.250000
# max      2456.000000  3025.000000  1994.000000

# %%
df.groupby("education")["balance"].describe().transpose()
# Out:
# education       primary     secondary      tertiary       unknown
# count        678.000000   2306.000000   1350.000000    187.000000
# mean        1411.544248   1196.814397   1775.423704   1701.245989
# std         3713.755021   2419.704664   3460.615109   2981.380992
# min         -966.000000  -2082.000000  -3313.000000   -715.000000
# 25%           65.250000     57.000000    102.000000     88.500000
# 50%          404.500000    385.500000    583.500000    574.000000
# 75%         1394.750000   1269.750000   1840.000000   2066.000000
# max        71188.000000  26452.000000  42045.000000  21244.000000

# %%
pd.crosstab(df["balance"], df["marital"])
# Out:
# marital  divorced  married  single
# balance
# -3313           0        1       0
# -2082           0        1       0
# -1746           0        1       0
# -1680           0        1       0
# -1400           0        1       0
# ...           ...      ...     ...
#  27069          0        1       0
#  27359          0        1       0
#  27733          0        0       1
#  42045          0        1       0
#  71188          0        1       0
#
# [2353 rows x 3 columns]

# %%
pd.crosstab(df["marital"], df["loan"], margins=True)
# Out:
# loan        no  yes   All
# marital
# divorced   438   90   528
# married   2344  453  2797
# single    1048  148  1196
# All       3830  691  4521

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
pd.crosstab(df["contact"], df["loan"], margins=True)
# Out:
# loan         no  yes   All
# contact
# cellular   2447  449  2896
# telephone   257   44   301
# unknown    1126  198  1324
# All        3830  691  4521

# %%
pd.crosstab(df["job"], df["loan"], margins=True)
# Out:
# loan             no  yes   All
# job
# admin.          387   91   478
# blue-collar     790  156   946
# entrepreneur    127   41   168
# housemaid        99   13   112
# management      849  120   969
# retired         198   32   230
# self-employed   153   30   183
# services        343   74   417
# student          83    1    84
# technician      649  119   768
# unemployed      115   13   128
# unknown          37    1    38
# All            3830  691  4521

# %%
df.groupby("loan")["balance"].mean()
# Out:
# loan
# no     1513.857963
# yes     917.163531
# Name: balance, dtype: float64

# %%
df.groupby("loan")["age"].mean()
# Out:
# loan
# no     41.220627
# yes    40.890014
# Name: age, dtype: float64

# %%
df.groupby("loan")["balance"].describe().transpose()
# Out:
# loan             no           yes
# count   3830.000000    691.000000
# mean    1513.857963    917.163531
# std     3121.230855   2229.886206
# min    -1746.000000  -3313.000000
# 25%       81.250000      8.500000
# 50%      480.000000    276.000000
# 75%     1582.750000    910.500000
# max    71188.000000  27069.000000

# %%
df.groupby("loan")["age"].describe().transpose()
# Out:
# loan            no         yes
# count  3830.000000  691.000000
# mean     41.220627   40.890014
# std      10.734900    9.651886
# min      19.000000   22.000000
# 25%      33.000000   33.000000
# 50%      39.000000   40.000000
# 75%      48.750000   49.000000
# max      87.000000   61.000000

# %%
df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
pd.crosstab(df["education"], df["loan"])
# Out:
# loan         no  yes
# education
# primary     584   94
# secondary  1890  416
# tertiary   1176  174
# unknown     180    7

# %%
df[(df["balance"]>1500) | (df["education"]=="secondary") & (df["marital"]=="married")]
# Out:
#       age          job  marital  education default  balance housing loan  \
# 0      30   unemployed  married    primary      no     1787      no   no
# 1      33     services  married  secondary      no     4789     yes  yes
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4513   49  blue-collar  married  secondary      no      322      no   no
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %% [markdown]
# # Loan status distribution

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="loan", data=df, palette="coolwarm")
plt.title("Loan Status Distribution")
plt.xlabel("Loan Taken")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Housing Loan vs Personal Loan Comparison

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="loan", hue="housing", data=df, palette="viridis")
plt.title("Comparison of Housing Loan vs Personal Loan")
plt.xlabel("Personal Loan Status")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Loan Distribution Across Different Jobs

# %%
plt.figure(figsize=(14,6))
sns.countplot(x="job", hue="loan", data=df, palette="coolwarm", order=df["job"].value_counts().index)
plt.xticks(rotation=90)
plt.title("Loan Status Across Different Job Types")
plt.xlabel("Job Type")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Balance Analysis for People Who Took Loans

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x="loan", y="balance", data=df, palette="pastel")
plt.ylim(-5000, 20000)
plt.title("Balance Distribution for People with and without Loans")
plt.xlabel("Personal Loan Status")
plt.ylabel("Balance Amount")
plt.show()

# %% [markdown]
# # Loan Approval Rate Based on Marital Status

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="marital", hue="loan", data=df, palette="Set2")
plt.title("Loan Approval Rate Based on Marital Status")
plt.xlabel("Marital Status")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Loan vs Education Level

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="education", hue="loan", data=df, palette="coolwarm")
plt.title("Loan Distribution Based on Education Level")
plt.xlabel("Education Level")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Age vs Loan Distribution

# %%
plt.figure(figsize=(12,5))
sns.histplot(data=df, x="age", hue="loan", multiple="stack", bins=30, palette="viridis")
plt.title("Age vs Loan Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
plt.boxplot(df["balance"])
plt.show()

# %%
sns.catplot(x="marital", y="duration", hue="loan", data=df)

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
sns.catplot(x="education", y="previous", hue="loan", data=df, kind="bar")

# %%
sns.catplot(y="education", hue="loan", data=df, kind="bar")

# %%
sns.histplot(df['marital'],bins=10,kde=True)
plt.show()

# %%
sns.histplot(df['education'],bins=10,kde=True)
plt.show()

# %%
sns.histplot(df['housing'],bins=10,kde=True)
plt.show()

# %%
sns.catplot(y="marital", x="education", hue="loan", data=df, kind="bar")

# %%
sns.catplot(x="loan", y="education", hue="marital", data=df, kind="bar", col="marital")
plt.show()

# %%
sns.scatterplot(x=df['education'], y=df['balance'], hue=df['loan'])
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
sns.scatterplot(x=df['education'], y=df['balance'], hue=df['poutcome'])
plt.show()

# %%
sns.relplot(x=df['loan'], y=df['duration'], col=df['marital'], col_wrap=2)
plt.show()

# %%
sns.pairplot(df,vars=continuous)
plt.show()

# %%
sns.pairplot(df,vars=discrete_count)
plt.show()
